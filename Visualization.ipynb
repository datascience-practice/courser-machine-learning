% %% [markdown]
% ## Line Plots

% %%
x = linspace(0, 10, 100);
y = x.^2;
plot(x,y)

% %% [markdown]
% ## Annotations

% %%
x = -1:0.01:1;
y = x.^2;
plot(x, y)
xlabel('time [s]')
ylabel('amplitude')
title('myplot')
legend('y(t)')
